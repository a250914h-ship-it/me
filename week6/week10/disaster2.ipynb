# %% [markdown]
# # Disaster Challenge Part 2: Function & Loop Visualization
#
# ## 課題の目的
# このノートブックでは、EM-DATの災害データを用いて、
# **自作関数とループ**を使ったデータ可視化を行う。
#
# - 関数(Function)を作成して再利用可能な可視化を作る
# - サンプル出力(Sample Output)で関数を確認
# - ループ(Loop)を使い、複数グラフや集計結果を自動生成する

# %%
import pandas as pd
import matplotlib.pyplot as plt

# データ読み込み
df = pd.read_csv("Week10/emdat.csv")  # ファイルパスを変更
df = df[["Start Year", "Disaster Type", "Region", "Total Deaths"]]
df = df.rename(columns={"Start Year": "Year"})
df["Year"] = df["Year"].astype(int)
df = df.fillna(0)

df.head()
